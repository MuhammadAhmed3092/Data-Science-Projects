# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel('ALLLEAGUESDATA.xlsx')
df
# Out:
#       League  Season      Home Team            Away Team  Home Goals  \
# 0       Eng1      20      Liverpool              Norwich           4
# 1       Eng1      20      Tottenham          Aston Villa           3
# 2       Eng1      20       C Palace              Everton           0
# 3       Eng1      20       West Ham             Man City           0
# 4       Eng1      20        Watford             Brighton           0
# ...      ...     ...            ...                  ...         ...
# 63184   Mex1      23         Toluca            Queretaro           4
# 63185   Mex1      23      Monterrey              Pachuca           0
# 63186   Mex1      23       San Luis               Tigres           0
# 63187   Mex1      23  Santos Laguna             Mazatlan           3
# 63188   Mex1      23           Leon  Tijuana de Caliente           2
#
#        Away Goals  Home FH  Away FH  Home Win     Draw  Away Win  Over 2,5  \
# 0               1        4        0    1140.0  10430.0   19630.0      1340
# 1               1        0        1    1390.0   5350.0    8420.0      1580
# 2               0        0        0    3370.0   3450.0    2270.0      2220
# 3               5        0        1   11110.0   6680.0    1270.0      1430
# 4               3        0        1    2050.0   3380.0    4120.0      2160
# ...           ...      ...      ...       ...      ...       ...       ...
# 63184           1        2        0    1880.0   4200.0    3850.0      1580
# 63185           0        0        0    2220.0   3460.0    3360.0      1950
# 63186           3        0        0    2910.0   3500.0    2460.0      1990
# 63187           0        0        0    1680.0   4410.0    4830.0      1540
# 63188           2        0        0    1810.0   4200.0    4180.0      1560
#
#        Under 2,5  Code 1  Code 2  Total Goals  FH Goals Winner HT Winner
# 0           3440    1002    1011            5         4      H         H
# 1           2520    1001    1003            4         1      H         A
# 2           1740    1012    1017            0         0      D         D
# 3           3030    1022    1009            5         1      A         A
# 4           1780    1025    1036            3         1      A         A
# ...          ...     ...     ...          ...       ...    ...       ...
# 63184       2490   41007   41011            5         2      H         H
# 63185       1930   41018   41004            0         0      D         D
# 63186       1900   41019   41005            3         0      A         D
# 63187       2610   41008   41021            3         0      H         D
# 63188       2540   41016   41006            4         0      D         D
#
# [63189 rows x 19 columns]

# %%
df.describe()
# Out:
#              Season    Home Goals    Away Goals       Home FH       Away FH  \
# count  63189.000000  63189.000000  63189.000000  63189.000000  63189.000000
# mean      21.562693      1.462517      1.197012      0.652408      0.529396
# std        1.108266      1.263394      1.141881      0.818801      0.739860
# min       20.000000      0.000000      0.000000      0.000000      0.000000
# 25%       21.000000      1.000000      0.000000      0.000000      0.000000
# 50%       22.000000      1.000000      1.000000      0.000000      0.000000
# 75%       23.000000      2.000000      2.000000      1.000000      1.000000
# max       23.000000     13.000000     13.000000      7.000000      7.000000
#
#            Home Win          Draw      Away Win      Over 2,5     Under 2,5  \
# count  63189.000000  63189.000000  63189.000000  63189.000000  63189.000000
# mean    2723.550655   3813.055904   4080.404955   1980.246562   1978.342433
# std     1800.138466    998.734819   3131.574746    387.432481    442.517940
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%     1810.000000   3300.000000   2450.000000   1720.000000   1690.000000
# 50%     2310.000000   3570.000000   3290.000000   1950.000000   1900.000000
# 75%     3020.000000   3990.000000   4580.000000   2210.000000   2180.000000
# max    47370.000000  17980.000000  76000.000000   4500.000000   8000.000000
#
#              Code 1        Code 2   Total Goals      FH Goals
# count  63189.000000  63189.000000  63189.000000  63189.000000
# mean   14555.952856  14555.944231      2.659529      1.181804
# std    11877.290462  11877.281687      1.652328      1.082685
# min     1001.000000   1001.000000      0.000000      0.000000
# 25%     3065.000000   3065.000000      1.000000      0.000000
# 50%    13019.000000  13019.000000      2.000000      1.000000
# 75%    24022.000000  24022.000000      4.000000      2.000000
# max    41021.000000  41021.000000     13.000000      7.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63189 entries, 0 to 63188
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   League       63189 non-null  object
#  1   Season       63189 non-null  int64
#  2   Home Team    63189 non-null  object
#  3   Away Team    63189 non-null  object
#  4   Home Goals   63189 non-null  int64
#  5   Away Goals   63189 non-null  int64
#  6   Home FH      63189 non-null  int64
#  7   Away FH      63189 non-null  int64
#  8   Home Win     63189 non-null  float64
#  9   Draw         63189 non-null  float64
#  10  Away Win     63189 non-null  float64
#  11  Over 2,5     63189 non-null  int64
#  12  Under 2,5    63189 non-null  int64
#  13  Code 1       63189 non-null  int64
#  14  Code 2       63189 non-null  int64
#  15  Total Goals  63189 non-null  int64
#  16  FH Goals     63189 non-null  int64
#  17  Winner       63189 non-null  object
#  18  HT Winner    63189 non-null  object
# dtypes: float64(3), int64(11), object(5)
# memory usage: 9.2+ MB

# %%
df.dtypes
# Out:
# League          object
# Season           int64
# Home Team       object
# Away Team       object
# Home Goals       int64
# Away Goals       int64
# Home FH          int64
# Away FH          int64
# Home Win       float64
# Draw           float64
# Away Win       float64
# Over 2,5         int64
# Under 2,5        int64
# Code 1           int64
# Code 2           int64
# Total Goals      int64
# FH Goals         int64
# Winner          object
# HT Winner       object
# dtype: object

# %%
df.isnull().sum()
# Out:
# League         0
# Season         0
# Home Team      0
# Away Team      0
# Home Goals     0
# Away Goals     0
# Home FH        0
# Away FH        0
# Home Win       0
# Draw           0
# Away Win       0
# Over 2,5       0
# Under 2,5      0
# Code 1         0
# Code 2         0
# Total Goals    0
# FH Goals       0
# Winner         0
# HT Winner      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
bold = "\033[1m"
reset = "\033[0m"
for col in df.columns:
    print(f"{bold}Value Counts of {col}")
    print(f"{bold}Column : {col}{reset}")
    print(df[col].value_counts())
    print("\n")
# Out:
# Value Counts of League
# Column : League
# Eng2    2208
# Eng4    2096
# Eng3    2056
# Eng5    1971
# Spa2    1848
#         ...
# Ser2     240
# Rom2     190
# Chi2     170
# Bel2     132
# Cro2     132
# Name: League, Length: 71, dtype: int64
#
#
# Value Counts of Season
# Column : Season
# 23    16747
# 22    16346
# 21    15812
# 20    14284
# Name: Season, dtype: int64
#
#
# Value Counts of Home Team
# Column : Home Team
# Newcastle                   126
# Gorica                      108
# Everton                      99
# Arsenal                      97
# Millwall                     92
#                            ...
# Yanbian                       5
# Shanghai Jiading Huilong      4
# Qingdao Youth Island          4
# Jinan Xingzhou                4
# Heilongjiang Ice City         3
# Name: Home Team, Length: 1379, dtype: int64
#
#
# Value Counts of Away Team
# Column : Away Team
# Newcastle              127
# Gorica                 108
# Arsenal                101
# Everton                 98
# Reading                 92
#                       ...
# Dongguan Guanlian        4
# Shijiazhuang Gongfu      4
# Nanjing City             4
# ziantep                  1
# Nagoia                   1
# Name: Away Team, Length: 1381, dtype: int64
#
#
# Value Counts of Home Goals
# Column : Home Goals
# 1     21198
# 0     15353
# 2     15064
# 3      7271
# 4      2836
# 5      1039
# 6       309
# 7        88
# 8        20
# 9         7
# 10        2
# 13        1
# 11        1
# Name: Home Goals, dtype: int64
#
#
# Value Counts of Away Goals
# Column : Away Goals
# 1     22473
# 0     19833
# 2     13034
# 3      5295
# 4      1841
# 5       507
# 6       157
# 7        35
# 8         8
# 9         3
# 13        1
# 10        1
# 12        1
# Name: Away Goals, dtype: int64
#
#
# Value Counts of Home FH
# Column : Home FH
# 0    33146
# 1    21207
# 2     6909
# 3     1568
# 4      307
# 5       46
# 6        4
# 7        2
# Name: Home FH, dtype: int64
#
#
# Value Counts of Away FH
# Column : Away FH
# 0    37481
# 1    19379
# 2     5139
# 3      998
# 4      164
# 5       24
# 6        3
# 7        1
# Name: Away FH, dtype: int64
#
#
# Value Counts of Home Win
# Column : Home Win
# 1930.0     584
# 1880.0     486
# 1850.0     434
# 2000.0     428
# 1680.0     409
#           ...
# 12700.0      1
# 17710.0      1
# 20100.0      1
# 14160.0      1
# 15480.0      1
# Name: Home Win, Length: 1319, dtype: int64
#
#
# Value Counts of Draw
# Column : Draw
# 3400.0     857
# 3500.0     824
# 3300.0     748
# 3600.0     734
# 3200.0     671
#           ...
# 8110.0       1
# 13840.0      1
# 9370.0       1
# 2260.0       1
# 9510.0       1
# Name: Draw, Length: 899, dtype: int64
#
#
# Value Counts of Away Win
# Column : Away Win
# 3000.00     291
# 2800.00     252
# 2300.00     248
# 2750.00     239
# 2450.00     237
#            ...
# 28790.00      1
# 0.48          1
# 23760.00      1
# 21420.00      1
# 0.51          1
# Name: Away Win, Length: 2049, dtype: int64
#
#
# Value Counts of Over 2,5
# Column : Over 2,5
# 1930    1198
# 1880     989
# 1850     988
# 1680     886
# 1650     829
#         ...
# 4300       1
# 3590       1
# 3670       1
# 3420       1
# 4500       1
# Name: Over 2,5, Length: 260, dtype: int64
#
#
# Value Counts of Under 2,5
# Column : Under 2,5
# 1930    1223
# 1850    1194
# 1680    1085
# 1880    1070
# 1650    1022
#         ...
# 5500       1
# 5690       1
# 4390       1
# 5170       1
# 1170       1
# Name: Under 2,5, Length: 378, dtype: int64
#
#
# Value Counts of Code 1
# Column : Code 1
# 1049     92
# 1029     92
# 1023     92
# 1005     92
# 1048     92
#          ..
# 39005     5
# 35058     4
# 35056     4
# 35054     4
# 35062     3
# Name: Code 1, Length: 1358, dtype: int64
#
#
# Value Counts of Code 2
# Column : Code 2
# 1028     92
# 1015     92
# 1039     92
# 1049     92
# 1033     92
#          ..
# 35061     4
# 35060     4
# 35055     4
# 35057     4
# 35059     4
# Name: Code 2, Length: 1358, dtype: int64
#
#
# Value Counts of Total Goals
# Column : Total Goals
# 2     15407
# 3     13871
# 1     11514
# 4      9095
# 5      5009
# 0      4819
# 6      2202
# 7       885
# 8       264
# 9        87
# 10       21
# 11        8
# 12        4
# 13        3
# Name: Total Goals, dtype: int64
#
#
# Value Counts of FH Goals
# Column : FH Goals
# 1    22869
# 0    19356
# 2    13564
# 3     5434
# 4     1542
# 5      349
# 6       60
# 7       15
# Name: FH Goals, dtype: int64
#
#
# Value Counts of Winner
# Column : Winner
# H    27121
# A    19551
# D    16517
# Name: Winner, dtype: int64
#
#
# Value Counts of HT Winner
# Column : HT Winner
# D    26467
# H    20816
# A    15906
# Name: HT Winner, dtype: int64

# %%
df.head(10)
# Out:
#   League  Season    Home Team    Away Team  Home Goals  Away Goals  Home FH  \
# 0   Eng1      20    Liverpool      Norwich           4           1        4
# 1   Eng1      20    Tottenham  Aston Villa           3           1        0
# 2   Eng1      20     C Palace      Everton           0           0        0
# 3   Eng1      20     West Ham     Man City           0           5        0
# 4   Eng1      20      Watford     Brighton           0           3        0
# 5   Eng1      20      Burnley  Southampton           3           0        0
# 6   Eng1      20  Bournemouth    Sheffield           1           1        0
# 7   Eng1      20    Newcastle      Arsenal           0           1        0
# 8   Eng1      20      Man Utd      Chelsea           4           0        1
# 9   Eng1      20    Leicester       Wolves           0           0        0
#
#    Away FH  Home Win     Draw  Away Win  Over 2,5  Under 2,5  Code 1  Code 2  \
# 0        0    1140.0  10430.0   19630.0      1340       3440    1002    1011
# 1        1    1390.0   5350.0    8420.0      1580       2520    1001    1003
# 2        0    3370.0   3450.0    2270.0      2220       1740    1012    1017
# 3        1   11110.0   6680.0    1270.0      1430       3030    1022    1009
# 4        1    2050.0   3380.0    4120.0      2160       1780    1025    1036
# 5        0    2710.0   3190.0    2900.0      2190       1760    1030    1004
# 6        0    1980.0   3670.0    4060.0      1940       1970    1063    1024
# 7        0    3360.0   3560.0    2250.0      1830       2090    1016    1018
# 8        0    2040.0   3440.0    4140.0      2050       1880    1020    1019
# 9        0    2500.0   3120.0    3300.0      2450       1630    1042    1031
#
#    Total Goals  FH Goals Winner HT Winner
# 0            5         4      H         H
# 1            4         1      H         A
# 2            0         0      D         D
# 3            5         1      A         A
# 4            3         1      A         A
# 5            3         0      H         D
# 6            2         0      D         D
# 7            1         0      A         D
# 8            4         1      H         H
# 9            0         0      D         D

# %%
df['Winner Team'] = ''

# %%
df.loc[df['Winner'] == 'H', 'Winner Team'] = df['Home Team']
df.loc[df['Winner'] == 'A', 'Winner Team'] = df['Away Team']
df.loc[df['Winner'] == 'D', 'Winner Team'] = 'Draw'

# %%
df['Half-Time Winner'] = ''
df.loc[df['HT Winner'] == 'H', 'Half-Time Winner'] = df['Home Team']
df.loc[df['HT Winner'] == 'A', 'Half-Time Winner'] = df['Away Team']
df.loc[df['HT Winner'] == 'D', 'Half-Time Winner'] = 'Draw'

# %%
df
# Out:
#       League  Season      Home Team            Away Team  Home Goals  \
# 0       Eng1      20      Liverpool              Norwich           4
# 1       Eng1      20      Tottenham          Aston Villa           3
# 2       Eng1      20       C Palace              Everton           0
# 3       Eng1      20       West Ham             Man City           0
# 4       Eng1      20        Watford             Brighton           0
# ...      ...     ...            ...                  ...         ...
# 63184   Mex1      23         Toluca            Queretaro           4
# 63185   Mex1      23      Monterrey              Pachuca           0
# 63186   Mex1      23       San Luis               Tigres           0
# 63187   Mex1      23  Santos Laguna             Mazatlan           3
# 63188   Mex1      23           Leon  Tijuana de Caliente           2
#
#        Away Goals  Home FH  Away FH  Home Win     Draw  ...  Over 2,5  \
# 0               1        4        0    1140.0  10430.0  ...      1340
# 1               1        0        1    1390.0   5350.0  ...      1580
# 2               0        0        0    3370.0   3450.0  ...      2220
# 3               5        0        1   11110.0   6680.0  ...      1430
# 4               3        0        1    2050.0   3380.0  ...      2160
# ...           ...      ...      ...       ...      ...  ...       ...
# 63184           1        2        0    1880.0   4200.0  ...      1580
# 63185           0        0        0    2220.0   3460.0  ...      1950
# 63186           3        0        0    2910.0   3500.0  ...      1990
# 63187           0        0        0    1680.0   4410.0  ...      1540
# 63188           2        0        0    1810.0   4200.0  ...      1560
#
#        Under 2,5  Code 1  Code 2  Total Goals  FH Goals  Winner HT Winner  \
# 0           3440    1002    1011            5         4       H         H
# 1           2520    1001    1003            4         1       H         A
# 2           1740    1012    1017            0         0       D         D
# 3           3030    1022    1009            5         1       A         A
# 4           1780    1025    1036            3         1       A         A
# ...          ...     ...     ...          ...       ...     ...       ...
# 63184       2490   41007   41011            5         2       H         H
# 63185       1930   41018   41004            0         0       D         D
# 63186       1900   41019   41005            3         0       A         D
# 63187       2610   41008   41021            3         0       H         D
# 63188       2540   41016   41006            4         0       D         D
#
#          Winner Team Half-Time Winner
# 0          Liverpool        Liverpool
# 1          Tottenham      Aston Villa
# 2               Draw             Draw
# 3           Man City         Man City
# 4           Brighton         Brighton
# ...              ...              ...
# 63184         Toluca           Toluca
# 63185           Draw             Draw
# 63186         Tigres             Draw
# 63187  Santos Laguna             Draw
# 63188           Draw             Draw
#
# [63189 rows x 21 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,8))
plt.subplot(1,2,1)
df['Winner'].value_counts().plot.pie(autopct = '%1.2f%%')
plt.title('Winner of match at Full Time')
plt.subplot(1,2,2)
df['HT Winner'].value_counts().plot.pie(autopct = '%1.2f%%')
plt.title("Winner of match at Half Time")
# Out:
# Text(0.5, 1.0, 'Winner of match at Half Time')

# %%
# log_winner = np.log(df['Winner'])
# print(log_winner.hist())

# %%
plt.figure(figsize=(12,8))
plt.subplot(1,2,1)
df['Total Goals'].value_counts().plot.pie(autopct='%1.2f%%')
plt.title('Total Goals at Full Time')
plt.subplot(1,2,2)
df['FH Goals'].value_counts().plot.pie(autopct='%1.2f%%')
plt.title('Total Goals at Half-Time')
# Out:
# Text(0.5, 1.0, 'Total Goals at Half-Time')

# %%
winner_counts = df['Winner Team'].value_counts().head(11)
winner = winner_counts[1:]
plt.figure(figsize=(20,8))
winner.plot(kind='bar')
plt.title('Top 10 Winner Teams',fontsize=25)
plt.xlabel('Winner Teams',fontsize=20)
plt.ylabel('Number Of Wins',fontsize=20)
plt.xticks(rotation=90)
plt.legend(fontsize=15)
plt.show()

# %%
htwinner_counts = df['Half-Time Winner'].value_counts().head(11)
htwinner = winner_counts[1:]
plt.figure(figsize=(20,8))
htwinner.plot(kind='bar')
plt.title('Top 10 Half Time Winner Teams',fontsize=25)
plt.xlabel('Half-Time Winner Teams',fontsize=20)
plt.ylabel('Number Of Wins',fontsize=20)
plt.xticks(rotation=90)
plt.legend(fontsize=15)
plt.show()

# %%
outcomes = ['Home Wins','Draw','Away Wins']
counts = [df['Winner'].value_counts()['H'], df['Winner'].value_counts()['D'], df['Winner'].value_counts()['A']]
plt.title("Distribution of Match Outcomes")
plt.bar(outcomes,counts)
plt.xlabel("Result")
plt.ylabel("Number of Wins")
plt.show()

# %%
cleansheets_teams=df[['Home Team','Away Team','Home Goals','Away Goals']]
clean_sheets = df[(df['Away Goals'] == 0) & (df['Home Goals'] == 0)]
clean_sheets_by_team = clean_sheets.groupby('Away Team')['Away Team'].count().add(clean_sheets.groupby('Home Team')['Home Team'].count(), fill_value=0)
clean_sheets_by_team = clean_sheets_by_team.sort_values(ascending=False)

top_10_teams = clean_sheets_by_team.head(10)

plt.figure(figsize=(20,8))
plt.bar(top_10_teams.index, top_10_teams)
plt.xlabel('Teams',fontsize=20)
plt.ylabel('Number of Clean Sheets',fontsize=20)
plt.title('Top 10 Teams with the Most Clean Sheets',fontsize=20)
plt.xticks(rotation=90)
plt.show()

# %%
outcomes = ['Home Win','Draw','Away Win']
counts = [df['Winner'].value_counts()['H'], df['Winner'].value_counts()['D'], df['Winner'].value_counts()['A']]
plt.title("Distribution of Match Outcomes")
plt.pie(counts, labels=outcomes, autopct='%1.1f%%')
plt.show()

# %%
seasons = df['Season']
home_goals = df['Home Goals']
away_goals = df['Away Goals']

plt.plot(seasons, home_goals, label = 'Home Goals')
plt.plot(seasons, away_goals, label = 'Away Goals')
plt.xlabel('Season')
plt.ylabel('Goals')
plt.title('Goals Scored by Home and Away Teams over the season')
plt.legend()
plt.show()

# %%
total_goals = df['Total Goals']

plt.hist(total_goals, bins=10)
plt.xlabel('Total Goals')
plt.ylabel('Times x amount of goals scored by a team')
plt.title('Distribution of Total Goals')
plt.show()

# %%
home_goals = df['Home Goals']
away_goals = df['Away Goals']

plt.scatter(home_goals, away_goals)
plt.xlabel('Home Goals')
plt.ylabel('Away Goals')
plt.title('Relationship b/w Home and Away goals')
plt.show()

# %%
teams = df['Home Team'].unique()
average_goals = []
for team in teams:
    home_avg = np.mean(df[df['Home Team'] == team]['Home Goals'])
    away_avg = np.mean(df[df['Away Team'] == team]['Away Goals'])
    average_goals.append((home_avg + away_avg) / 2)

plt.figure(figsize=(20,8))    
plt.bar(teams, average_goals)
plt.xlabel('Team')
plt.ylabel('Average Goals')
plt.title('Average Goals Scored by Each Team')
plt.show()
